# %% [markdown]
# ### TASK 2 - Student Number: 22202307

# %% [markdown]
# ### Data Analysis and Pre-processing

# %% [markdown]
# This Python code imports several important libraries and modules for data analysis and manipulation:
#
# pandas is a popular library for data manipulation and analysis in Python.
# json is a built-in module for working with JSON data, which is commonly used in web applications and APIs.
# datetime is a module in the Python standard library that provides methods for working with dates and times.

# %%
import pandas as pd;
import json
from datetime import datetime

# %% [markdown]
# Retrieve Data

# %% [markdown]
# This code reads the contents of a JSON file named "data.json" using the "open()" function in read mode ('r') and saves the loaded data into the "data" variable using the "json.load()" method. The "with" statement is used to ensure that the file is closed properly after it is read.  Once the date is retrieved,closing the file should be executed to avoid exceptions.

# %%
with open('data.json', 'r') as file:
    data = json.load(file)

file.close()

# %% [markdown]
# Before analysing the data, it should be converted to a pandas dataframe as it is a convenient way to work with nested or hierarchical JSON data, where each where each element can have multiple levels of nesting. In the earthquake data, the whole data is inside the key 'features'. And so we are using that key and take the whole data which is saved to the variable 'df'. The converted data is printed in the next line.

# %%
df = pd.json_normalize(data['features'])
df
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  \
# 0           1679774696230          None
# 1           1679774210394          None
# 2           1679773719021          None
# 3           1679771562802          None
# 4           1679772243330          None
# ...                   ...           ...
# 12458       1677811394893          None
# 12459       1677722441196          None
# 12460       1677612340130          None
# 12461       1677190347330          None
# 12462       1677290298680          None
#
#                                           properties.url  \
# 0      https://earthquake.usgs.gov/earthquakes/eventp...
# 1      https://earthquake.usgs.gov/earthquakes/eventp...
# 2      https://earthquake.usgs.gov/earthquakes/eventp...
# 3      https://earthquake.usgs.gov/earthquakes/eventp...
# 4      https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                  ...
# 12458  https://earthquake.usgs.gov/earthquakes/eventp...
# 12459  https://earthquake.usgs.gov/earthquakes/eventp...
# 12460  https://earthquake.usgs.gov/earthquakes/eventp...
# 12461  https://earthquake.usgs.gov/earthquakes/eventp...
# 12462  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                        properties.detail  properties.felt  \
# 0      https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 1      https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 2      https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 3      https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 4      https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# ...                                                  ...              ...
# 12458  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 12459  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 12460  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 12461  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
# 12462  https://earthquake.usgs.gov/earthquakes/feed/v...              NaN
#
#        ...                                   properties.types  properties.nst  \
# 0      ...  ,focal-mechanism,nearby-cities,origin,phase-da...            59.0
# 1      ...                ,nearby-cities,origin,scitech-link,             8.0
# 2      ...                                ,origin,phase-data,             NaN
# 3      ...                                ,origin,phase-data,             NaN
# 4      ...                                ,origin,phase-data,             6.0
# ...    ...                                                ...             ...
# 12458  ...                                ,origin,phase-data,             NaN
# 12459  ...                                ,origin,phase-data,             NaN
# 12460  ...                                ,origin,phase-data,            42.0
# 12461  ...                                ,origin,phase-data,             7.0
# 12462  ...                                ,origin,phase-data,             4.0
#
#       properties.dmin properties.rms  properties.gap  properties.magType  \
# 0             0.01177           0.19            30.0                  ml
# 1             0.40720           0.18           189.0                  ml
# 2                 NaN           0.57             NaN                  ml
# 3                 NaN           0.54             NaN                  ml
# 4             0.16040           0.07           267.0                  md
# ...               ...            ...             ...                 ...
# 12458             NaN           0.35             NaN                  ml
# 12459             NaN           0.17             NaN                  ml
# 12460             NaN           0.12           140.0                  md
# 12461         0.04425           0.19           199.0                  ml
# 12462             NaN           0.03           291.0                  ml
#
#       properties.type                                   properties.title  \
# 0          earthquake             M 1.8 - 5km WNW of Borrego Springs, CA
# 1          earthquake                      M 2.1 - 1km SSW of Santee, CA
# 2          earthquake                            M 2.0 - Southern Alaska
# 3          earthquake        M 1.2 - 33 km NNE of Four Mile Road, Alaska
# 4          earthquake  M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...
# ...               ...                                                ...
# 12458      earthquake                           M 2.1 - Alaska Peninsula
# 12459      earthquake               M 1.6 - 39 km W of Salamatof, Alaska
# 12460      earthquake                 M 2.2 - 9 km ENE of Pāhala, Hawaii
# 12461      earthquake              M 1.2 - 16 km S of Harrah, Washington
# 12462      earthquake      M 0.5 - Fox Islands, Aleutian Islands, Alaska
#
#       geometry.type                             geometry.coordinates
# 0             Point                  [-116.4311676, 33.267334, 4.56]
# 1             Point                 [-116.9778333, 32.8308333, 5.19]
# 2             Point                          [-147.0013, 61.2602, 0]
# 3             Point                         [-148.8985, 64.89, 16.7]
# 4             Point               [-64.826, 18.4843333333333, 75.75]
# ...             ...                                              ...
# 12458         Point                        [-155.3965, 58.1839, 1.6]
# 12459         Point                       [-152.0289, 60.6776, 82.4]
# 12460         Point     [-155.395166666667, 19.2408333333333, 30.91]
# 12461         Point  [-120.57866666666666, 46.25533333333333, 12.96]
# 12462         Point      [-166.884166666667, 53.6846666666667, 8.77]
#
# [12463 rows x 30 columns]

# %% [markdown]
# ### Data Pre processing

# %% [markdown]
# In the below cell, different functions are written to perform the below tasks:
#
# *   Convert the co-ordinates to List and create a new column for latitude and longitude and Depth.
# *   Remove Unused columns.
# *   Convert the event occurred date from milliseconds to UTC date format.
# *   Check the number of duplicate records.
# *   Perform encoding for the tsunami column as categorical data will be better for visualization purpose.
# *   Drop the existing tsunami column

# %%
def split_coordinates(data):
    # Convert the co-ordinates to List and create a new column for latitude and longitude and Depth
    df[['Longitude', 'Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist(),
                                                            index=df.index)
    return df

# Columns such as url, details of earthquake and felt are found to be not required for analysis as they do not provide any meaningful insights.
def drop_unused_columns(df):
    df.drop(['geometry.coordinates'], axis=1, inplace=True)
    df.drop(['properties.url'], axis=1, inplace=True)
    df.drop(['properties.detail'], axis=1, inplace=True)
    df.drop(['properties.felt'], axis=1, inplace=True)
    return df

# milliseconds to date  conversion
def dateConversion(df):
  df['date'] = pd.to_datetime(df['properties.time'], unit='ms')
  df['date'] = df['date'].dt.date
  return df

def check_for_duplicate_records(earthquake_df):
    # Display the Number of Duplicate records in the dataframe
    print(f"There are {earthquake_df.duplicated().sum()} duplicate records found in inputdataframe.")

def create_new_column_for_tsunami(predicted_dataframe):
    # Raw data has a column "flg tsunami" having value 'tsunami' if the earthquake or volcano triggered tsunami or not
    # For making it easy for visualization purpose,create a new column with values as 'Yes' or 'No'
    predicted_dataframe.loc[predicted_dataframe['properties.tsunami'] == 1, 'tsunami_occurred'] = 'Yes'
    predicted_dataframe.loc[predicted_dataframe['properties.tsunami'] != 1, 'tsunami_occurred'] = 'No'
    # After creating a new column,drop the existing 'tsunami' column from raw data
    predicted_dataframe.drop(['properties.tsunami'], axis=1, inplace=True)
    # Drop the existing ID column as it will throw exception while merging with other dataframes when they have same keys
    # predicted_dataframe.drop(['id'], axis=1, inplace=True)

    return predicted_dataframe

# %% [markdown]
# Function Call to split the co-ordinates and drop the unused columns

# %%
split_coordinates(df);
drop_unused_columns(df)
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  properties.cdi  properties.mmi  \
# 0           1679774696230          None             NaN             NaN
# 1           1679774210394          None             NaN             NaN
# 2           1679773719021          None             NaN             NaN
# 3           1679771562802          None             NaN             NaN
# 4           1679772243330          None             NaN             NaN
# ...                   ...           ...             ...             ...
# 12458       1677811394893          None             NaN             NaN
# 12459       1677722441196          None             NaN             NaN
# 12460       1677612340130          None             NaN             NaN
# 12461       1677190347330          None             NaN             NaN
# 12462       1677290298680          None             NaN             NaN
#
#       properties.alert  ... properties.dmin  properties.rms  properties.gap  \
# 0                 None  ...         0.01177            0.19            30.0
# 1                 None  ...         0.40720            0.18           189.0
# 2                 None  ...             NaN            0.57             NaN
# 3                 None  ...             NaN            0.54             NaN
# 4                 None  ...         0.16040            0.07           267.0
# ...                ...  ...             ...             ...             ...
# 12458             None  ...             NaN            0.35             NaN
# 12459             None  ...             NaN            0.17             NaN
# 12460             None  ...             NaN            0.12           140.0
# 12461             None  ...         0.04425            0.19           199.0
# 12462             None  ...             NaN            0.03           291.0
#
#       properties.magType properties.type  \
# 0                     ml      earthquake
# 1                     ml      earthquake
# 2                     ml      earthquake
# 3                     ml      earthquake
# 4                     md      earthquake
# ...                  ...             ...
# 12458                 ml      earthquake
# 12459                 ml      earthquake
# 12460                 md      earthquake
# 12461                 ml      earthquake
# 12462                 ml      earthquake
#
#                                         properties.title geometry.type  \
# 0                 M 1.8 - 5km WNW of Borrego Springs, CA         Point
# 1                          M 2.1 - 1km SSW of Santee, CA         Point
# 2                                M 2.0 - Southern Alaska         Point
# 3            M 1.2 - 33 km NNE of Four Mile Road, Alaska         Point
# 4      M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...         Point
# ...                                                  ...           ...
# 12458                           M 2.1 - Alaska Peninsula         Point
# 12459               M 1.6 - 39 km W of Salamatof, Alaska         Point
# 12460                 M 2.2 - 9 km ENE of Pāhala, Hawaii         Point
# 12461              M 1.2 - 16 km S of Harrah, Washington         Point
# 12462      M 0.5 - Fox Islands, Aleutian Islands, Alaska         Point
#
#         Longitude   Latitude  Depth
# 0     -116.431168  33.267334   4.56
# 1     -116.977833  32.830833   5.19
# 2     -147.001300  61.260200   0.00
# 3     -148.898500  64.890000  16.70
# 4      -64.826000  18.484333  75.75
# ...           ...        ...    ...
# 12458 -155.396500  58.183900   1.60
# 12459 -152.028900  60.677600  82.40
# 12460 -155.395167  19.240833  30.91
# 12461 -120.578667  46.255333  12.96
# 12462 -166.884167  53.684667   8.77
#
# [12463 rows x 29 columns]

# %% [markdown]
# Inorder to gather more insights from data, it is important to know the datatype of the columns available

# %%
print(df.dtypes)
# Out:
# type                   object
# id                     object
# properties.mag        float64
# properties.place       object
# properties.time         int64
# properties.updated      int64
# properties.tz          object
# properties.cdi        float64
# properties.mmi        float64
# properties.alert       object
# properties.status      object
# properties.tsunami      int64
# properties.sig          int64
# properties.net         object
# properties.code        object
# properties.ids         object
# properties.sources     object
# properties.types       object
# properties.nst        float64
# properties.dmin       float64
# properties.rms        float64
# properties.gap        float64
# properties.magType     object
# properties.type        object
# properties.title       object
# geometry.type          object
# Longitude             float64
# Latitude              float64
# Depth                 float64
# dtype: object

# %% [markdown]
# Function call to convert the date in milliseconds format to UTC format.

# %%
dateConversion(df)
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  properties.cdi  properties.mmi  \
# 0           1679774696230          None             NaN             NaN
# 1           1679774210394          None             NaN             NaN
# 2           1679773719021          None             NaN             NaN
# 3           1679771562802          None             NaN             NaN
# 4           1679772243330          None             NaN             NaN
# ...                   ...           ...             ...             ...
# 12458       1677811394893          None             NaN             NaN
# 12459       1677722441196          None             NaN             NaN
# 12460       1677612340130          None             NaN             NaN
# 12461       1677190347330          None             NaN             NaN
# 12462       1677290298680          None             NaN             NaN
#
#       properties.alert  ... properties.rms  properties.gap  \
# 0                 None  ...           0.19            30.0
# 1                 None  ...           0.18           189.0
# 2                 None  ...           0.57             NaN
# 3                 None  ...           0.54             NaN
# 4                 None  ...           0.07           267.0
# ...                ...  ...            ...             ...
# 12458             None  ...           0.35             NaN
# 12459             None  ...           0.17             NaN
# 12460             None  ...           0.12           140.0
# 12461             None  ...           0.19           199.0
# 12462             None  ...           0.03           291.0
#
#        properties.magType properties.type  \
# 0                      ml      earthquake
# 1                      ml      earthquake
# 2                      ml      earthquake
# 3                      ml      earthquake
# 4                      md      earthquake
# ...                   ...             ...
# 12458                  ml      earthquake
# 12459                  ml      earthquake
# 12460                  md      earthquake
# 12461                  ml      earthquake
# 12462                  ml      earthquake
#
#                                         properties.title geometry.type  \
# 0                 M 1.8 - 5km WNW of Borrego Springs, CA         Point
# 1                          M 2.1 - 1km SSW of Santee, CA         Point
# 2                                M 2.0 - Southern Alaska         Point
# 3            M 1.2 - 33 km NNE of Four Mile Road, Alaska         Point
# 4      M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...         Point
# ...                                                  ...           ...
# 12458                           M 2.1 - Alaska Peninsula         Point
# 12459               M 1.6 - 39 km W of Salamatof, Alaska         Point
# 12460                 M 2.2 - 9 km ENE of Pāhala, Hawaii         Point
# 12461              M 1.2 - 16 km S of Harrah, Washington         Point
# 12462      M 0.5 - Fox Islands, Aleutian Islands, Alaska         Point
#
#         Longitude   Latitude  Depth        date
# 0     -116.431168  33.267334   4.56  2023-03-25
# 1     -116.977833  32.830833   5.19  2023-03-25
# 2     -147.001300  61.260200   0.00  2023-03-25
# 3     -148.898500  64.890000  16.70  2023-03-25
# 4      -64.826000  18.484333  75.75  2023-03-25
# ...           ...        ...    ...         ...
# 12458 -155.396500  58.183900   1.60  2023-02-23
# 12459 -152.028900  60.677600  82.40  2023-02-23
# 12460 -155.395167  19.240833  30.91  2023-02-23
# 12461 -120.578667  46.255333  12.96  2023-02-23
# 12462 -166.884167  53.684667   8.77  2023-02-23
#
# [12463 rows x 30 columns]

# %% [markdown]
# ### Extract City Names
#
# The place where the event occurred is provided in the 'properties.place' column. But it has additional details such as the distance from the main city. In order to obtain the city details, lambda expression is implemented to split the city name from the 'properties.place' column

# %%
unique_names = df['properties.place'].value_counts()
df['place_name'] = df['properties.place'].apply(lambda x: x.split(',')[-1])
df
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  properties.cdi  properties.mmi  \
# 0           1679774696230          None             NaN             NaN
# 1           1679774210394          None             NaN             NaN
# 2           1679773719021          None             NaN             NaN
# 3           1679771562802          None             NaN             NaN
# 4           1679772243330          None             NaN             NaN
# ...                   ...           ...             ...             ...
# 12458       1677811394893          None             NaN             NaN
# 12459       1677722441196          None             NaN             NaN
# 12460       1677612340130          None             NaN             NaN
# 12461       1677190347330          None             NaN             NaN
# 12462       1677290298680          None             NaN             NaN
#
#       properties.alert  ... properties.gap  properties.magType  \
# 0                 None  ...           30.0                  ml
# 1                 None  ...          189.0                  ml
# 2                 None  ...            NaN                  ml
# 3                 None  ...            NaN                  ml
# 4                 None  ...          267.0                  md
# ...                ...  ...            ...                 ...
# 12458             None  ...            NaN                  ml
# 12459             None  ...            NaN                  ml
# 12460             None  ...          140.0                  md
# 12461             None  ...          199.0                  ml
# 12462             None  ...          291.0                  ml
#
#        properties.type                                   properties.title  \
# 0           earthquake             M 1.8 - 5km WNW of Borrego Springs, CA
# 1           earthquake                      M 2.1 - 1km SSW of Santee, CA
# 2           earthquake                            M 2.0 - Southern Alaska
# 3           earthquake        M 1.2 - 33 km NNE of Four Mile Road, Alaska
# 4           earthquake  M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...
# ...                ...                                                ...
# 12458       earthquake                           M 2.1 - Alaska Peninsula
# 12459       earthquake               M 1.6 - 39 km W of Salamatof, Alaska
# 12460       earthquake                 M 2.2 - 9 km ENE of Pāhala, Hawaii
# 12461       earthquake              M 1.2 - 16 km S of Harrah, Washington
# 12462       earthquake      M 0.5 - Fox Islands, Aleutian Islands, Alaska
#
#       geometry.type   Longitude   Latitude  Depth        date  \
# 0             Point -116.431168  33.267334   4.56  2023-03-25
# 1             Point -116.977833  32.830833   5.19  2023-03-25
# 2             Point -147.001300  61.260200   0.00  2023-03-25
# 3             Point -148.898500  64.890000  16.70  2023-03-25
# 4             Point  -64.826000  18.484333  75.75  2023-03-25
# ...             ...         ...        ...    ...         ...
# 12458         Point -155.396500  58.183900   1.60  2023-02-23
# 12459         Point -152.028900  60.677600  82.40  2023-02-23
# 12460         Point -155.395167  19.240833  30.91  2023-02-23
# 12461         Point -120.578667  46.255333  12.96  2023-02-23
# 12462         Point -166.884167  53.684667   8.77  2023-02-23
#
#                  place_name
# 0                        CA
# 1                        CA
# 2           Southern Alaska
# 3                    Alaska
# 4       U.S. Virgin Islands
# ...                     ...
# 12458      Alaska Peninsula
# 12459                Alaska
# 12460                Hawaii
# 12461            Washington
# 12462                Alaska
#
# [12463 rows x 31 columns]

# %%
check_for_duplicate_records(df)
# Out:
# There are 0 duplicate records found in inputdataframe.

# %%
create_new_column_for_tsunami(df)
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  properties.cdi  properties.mmi  \
# 0           1679774696230          None             NaN             NaN
# 1           1679774210394          None             NaN             NaN
# 2           1679773719021          None             NaN             NaN
# 3           1679771562802          None             NaN             NaN
# 4           1679772243330          None             NaN             NaN
# ...                   ...           ...             ...             ...
# 12458       1677811394893          None             NaN             NaN
# 12459       1677722441196          None             NaN             NaN
# 12460       1677612340130          None             NaN             NaN
# 12461       1677190347330          None             NaN             NaN
# 12462       1677290298680          None             NaN             NaN
#
#       properties.alert  ... properties.magType  properties.type  \
# 0                 None  ...                 ml       earthquake
# 1                 None  ...                 ml       earthquake
# 2                 None  ...                 ml       earthquake
# 3                 None  ...                 ml       earthquake
# 4                 None  ...                 md       earthquake
# ...                ...  ...                ...              ...
# 12458             None  ...                 ml       earthquake
# 12459             None  ...                 ml       earthquake
# 12460             None  ...                 md       earthquake
# 12461             None  ...                 ml       earthquake
# 12462             None  ...                 ml       earthquake
#
#                                         properties.title geometry.type  \
# 0                 M 1.8 - 5km WNW of Borrego Springs, CA         Point
# 1                          M 2.1 - 1km SSW of Santee, CA         Point
# 2                                M 2.0 - Southern Alaska         Point
# 3            M 1.2 - 33 km NNE of Four Mile Road, Alaska         Point
# 4      M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...         Point
# ...                                                  ...           ...
# 12458                           M 2.1 - Alaska Peninsula         Point
# 12459               M 1.6 - 39 km W of Salamatof, Alaska         Point
# 12460                 M 2.2 - 9 km ENE of Pāhala, Hawaii         Point
# 12461              M 1.2 - 16 km S of Harrah, Washington         Point
# 12462      M 0.5 - Fox Islands, Aleutian Islands, Alaska         Point
#
#         Longitude   Latitude  Depth        date            place_name  \
# 0     -116.431168  33.267334   4.56  2023-03-25                    CA
# 1     -116.977833  32.830833   5.19  2023-03-25                    CA
# 2     -147.001300  61.260200   0.00  2023-03-25       Southern Alaska
# 3     -148.898500  64.890000  16.70  2023-03-25                Alaska
# 4      -64.826000  18.484333  75.75  2023-03-25   U.S. Virgin Islands
# ...           ...        ...    ...         ...                   ...
# 12458 -155.396500  58.183900   1.60  2023-02-23      Alaska Peninsula
# 12459 -152.028900  60.677600  82.40  2023-02-23                Alaska
# 12460 -155.395167  19.240833  30.91  2023-02-23                Hawaii
# 12461 -120.578667  46.255333  12.96  2023-02-23            Washington
# 12462 -166.884167  53.684667   8.77  2023-02-23                Alaska
#
#        tsunami_occurred
# 0                    No
# 1                    No
# 2                    No
# 3                    No
# 4                    No
# ...                 ...
# 12458                No
# 12459                No
# 12460                No
# 12461                No
# 12462                No
#
# [12463 rows x 31 columns]

# %% [markdown]
# This code defines a function called "earthquakeMagnitude" that takes a pandas DataFrame object named "predicted_dataframe" as an argument. This function maps the abbreviation of different types of earthquake magnitudes to their full names in the DataFrame using the "loc" method and conditional statements. The mapped magnitude names are stored in a new column named "magnitude" in the DataFrame. The function returns the updated DataFrame. Finally, the function is called with a pandas DataFrame named "df" as an argument.

# %%
# MD: Duration magnitude
# ML: Local magnitude
# MS: Surface wave magnitude
# MW: Moment magnitude
# ME: Energy magnitude
# MI: Nuttli magnitude
# MB: Body-wave magnitude
# Mlg: Gutenberg-Richter magnitude
# md ml ms mw me mi mb mlg abbreviation


def earthquakeMagnitude(predicted_dataframe):
    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'md', 'magnitude'] = 'Duration magnitude'
    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'ml', 'magnitude'] = 'Local magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'ms', 'magnitude'] = 'Surface wave magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'mw', 'magnitude'] = 'Moment magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'me', 'magnitude'] = 'Energy magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'mi', 'magnitude'] = 'Nuttli magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'mb', 'magnitude'] = 'Body-wave magnitude'

    predicted_dataframe.loc[predicted_dataframe['properties.magType'] == 'mlg', 'magnitude'] = 'Gutenberg-Richter magnitude'

    return predicted_dataframe
earthquakeMagnitude(df)
# Out:
#           type            id  properties.mag  \
# 0      Feature    ci40189903            1.79
# 1      Feature    ci40189895            2.13
# 2      Feature  ak0233v8qay0            2.00
# 3      Feature  ak0233v8ikzw            1.20
# 4      Feature    pr71401523            3.21
# ...        ...           ...             ...
# 12458  Feature  ak0232hn4xtc            2.10
# 12459  Feature  ak0232hn4dmo            1.60
# 12460  Feature    hv73329557            2.24
# 12461  Feature    uw61899432            1.16
# 12462  Feature    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#        properties.updated properties.tz  properties.cdi  properties.mmi  \
# 0           1679774696230          None             NaN             NaN
# 1           1679774210394          None             NaN             NaN
# 2           1679773719021          None             NaN             NaN
# 3           1679771562802          None             NaN             NaN
# 4           1679772243330          None             NaN             NaN
# ...                   ...           ...             ...             ...
# 12458       1677811394893          None             NaN             NaN
# 12459       1677722441196          None             NaN             NaN
# 12460       1677612340130          None             NaN             NaN
# 12461       1677190347330          None             NaN             NaN
# 12462       1677290298680          None             NaN             NaN
#
#       properties.alert  ... properties.type  \
# 0                 None  ...      earthquake
# 1                 None  ...      earthquake
# 2                 None  ...      earthquake
# 3                 None  ...      earthquake
# 4                 None  ...      earthquake
# ...                ...  ...             ...
# 12458             None  ...      earthquake
# 12459             None  ...      earthquake
# 12460             None  ...      earthquake
# 12461             None  ...      earthquake
# 12462             None  ...      earthquake
#
#                                         properties.title geometry.type  \
# 0                 M 1.8 - 5km WNW of Borrego Springs, CA         Point
# 1                          M 2.1 - 1km SSW of Santee, CA         Point
# 2                                M 2.0 - Southern Alaska         Point
# 3            M 1.2 - 33 km NNE of Four Mile Road, Alaska         Point
# 4      M 3.2 - 17 km NNW of Cruz Bay, U.S. Virgin Isl...         Point
# ...                                                  ...           ...
# 12458                           M 2.1 - Alaska Peninsula         Point
# 12459               M 1.6 - 39 km W of Salamatof, Alaska         Point
# 12460                 M 2.2 - 9 km ENE of Pāhala, Hawaii         Point
# 12461              M 1.2 - 16 km S of Harrah, Washington         Point
# 12462      M 0.5 - Fox Islands, Aleutian Islands, Alaska         Point
#
#         Longitude   Latitude  Depth        date            place_name  \
# 0     -116.431168  33.267334   4.56  2023-03-25                    CA
# 1     -116.977833  32.830833   5.19  2023-03-25                    CA
# 2     -147.001300  61.260200   0.00  2023-03-25       Southern Alaska
# 3     -148.898500  64.890000  16.70  2023-03-25                Alaska
# 4      -64.826000  18.484333  75.75  2023-03-25   U.S. Virgin Islands
# ...           ...        ...    ...         ...                   ...
# 12458 -155.396500  58.183900   1.60  2023-02-23      Alaska Peninsula
# 12459 -152.028900  60.677600  82.40  2023-02-23                Alaska
# 12460 -155.395167  19.240833  30.91  2023-02-23                Hawaii
# 12461 -120.578667  46.255333  12.96  2023-02-23            Washington
# 12462 -166.884167  53.684667   8.77  2023-02-23                Alaska
#
#        tsunami_occurred           magnitude
# 0                    No     Local magnitude
# 1                    No     Local magnitude
# 2                    No     Local magnitude
# 3                    No     Local magnitude
# 4                    No  Duration magnitude
# ...                 ...                 ...
# 12458                No     Local magnitude
# 12459                No     Local magnitude
# 12460                No  Duration magnitude
# 12461                No     Local magnitude
# 12462                No     Local magnitude
#
# [12463 rows x 32 columns]

# %% [markdown]
# This code drops multiple columns from a pandas DataFrame object named "df". The "drop()" method is used with the "inplace=True" parameter to remove the specified columns from the DataFrame permanently.

# %%
df.drop(['properties.tz'], axis=1, inplace=True)
df.drop(['properties.cdi'], axis=1, inplace=True)
df.drop(['properties.mmi'], axis=1, inplace=True)
df.drop(['properties.alert'], axis=1, inplace=True)
df.drop(['properties.updated'], axis=1, inplace=True)
df.drop(['properties.net'], axis=1, inplace=True)
df.drop(['properties.code'], axis=1, inplace=True)
df.drop(['properties.ids'], axis=1, inplace=True)
df.drop(['type'], axis=1, inplace=True)
df.drop(['properties.sources'], axis=1, inplace=True)
df.drop(['properties.magType'], axis=1, inplace=True)
df.drop(['properties.title'], axis=1, inplace=True)

# %% [markdown]
# Below it calculates the total number of rows in a pandas DataFrame object named "df" using the built-in "len()" function. The result is stored in the variable "num_rows". The print statement then displays the total number of rows

# %%
# get the total number of rows
num_rows = len(df)

# print the result
print("Total number of rows:", num_rows)
# Out:
# Total number of rows: 12463

# %% [markdown]
# counts the number of missing or null values in each column of a pandas. The resulting Series object containing the count of missing values for each column is stored in the variable "missing_values".

# %%
# count the number of missing values in each column
missing_values = df.isnull().sum()

# print the result
print(missing_values)
# Out:
# id                      0
# properties.mag          0
# properties.place        0
# properties.time         0
# properties.status       0
# properties.sig          0
# properties.types        0
# properties.nst       3465
# properties.dmin      6539
# properties.rms          0
# properties.gap       3466
# properties.type         0
# geometry.type           0
# Longitude               0
# Latitude                0
# Depth                   0
# date                    0
# place_name              0
# tsunami_occurred        0
# magnitude             138
# dtype: int64

# %% [markdown]
# We remove the specified columns from the DataFrame permanently

# %%
df = df.drop(columns=['properties.dmin'])
df = df.drop(columns=['properties.nst'])
df = df.drop(columns=['properties.gap'])
df
# Out:
#                  id  properties.mag  \
# 0        ci40189903            1.79
# 1        ci40189895            2.13
# 2      ak0233v8qay0            2.00
# 3      ak0233v8ikzw            1.20
# 4        pr71401523            3.21
# ...             ...             ...
# 12458  ak0232hn4xtc            2.10
# 12459  ak0232hn4dmo            1.60
# 12460    hv73329557            2.24
# 12461    uw61899432            1.16
# 12462    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#       properties.status  properties.sig  \
# 0             automatic              49
# 1             automatic              70
# 2             automatic              62
# 3             automatic              22
# 4              reviewed             159
# ...                 ...             ...
# 12458          reviewed              68
# 12459          reviewed              39
# 12460          reviewed              77
# 12461          reviewed              21
# 12462          reviewed               4
#
#                                         properties.types  properties.rms  \
# 0      ,focal-mechanism,nearby-cities,origin,phase-da...            0.19
# 1                    ,nearby-cities,origin,scitech-link,            0.18
# 2                                    ,origin,phase-data,            0.57
# 3                                    ,origin,phase-data,            0.54
# 4                                    ,origin,phase-data,            0.07
# ...                                                  ...             ...
# 12458                                ,origin,phase-data,            0.35
# 12459                                ,origin,phase-data,            0.17
# 12460                                ,origin,phase-data,            0.12
# 12461                                ,origin,phase-data,            0.19
# 12462                                ,origin,phase-data,            0.03
#
#       properties.type geometry.type   Longitude   Latitude  Depth        date  \
# 0          earthquake         Point -116.431168  33.267334   4.56  2023-03-25
# 1          earthquake         Point -116.977833  32.830833   5.19  2023-03-25
# 2          earthquake         Point -147.001300  61.260200   0.00  2023-03-25
# 3          earthquake         Point -148.898500  64.890000  16.70  2023-03-25
# 4          earthquake         Point  -64.826000  18.484333  75.75  2023-03-25
# ...               ...           ...         ...        ...    ...         ...
# 12458      earthquake         Point -155.396500  58.183900   1.60  2023-02-23
# 12459      earthquake         Point -152.028900  60.677600  82.40  2023-02-23
# 12460      earthquake         Point -155.395167  19.240833  30.91  2023-02-23
# 12461      earthquake         Point -120.578667  46.255333  12.96  2023-02-23
# 12462      earthquake         Point -166.884167  53.684667   8.77  2023-02-23
#
#                  place_name tsunami_occurred           magnitude
# 0                        CA               No     Local magnitude
# 1                        CA               No     Local magnitude
# 2           Southern Alaska               No     Local magnitude
# 3                    Alaska               No     Local magnitude
# 4       U.S. Virgin Islands               No  Duration magnitude
# ...                     ...              ...                 ...
# 12458      Alaska Peninsula               No     Local magnitude
# 12459                Alaska               No     Local magnitude
# 12460                Hawaii               No  Duration magnitude
# 12461            Washington               No     Local magnitude
# 12462                Alaska               No     Local magnitude
#
# [12463 rows x 17 columns]

# %% [markdown]
# drops rows that have missing values in the 'magnitude' column. The resulting DataFrame with the missing values removed is then assigned back to the variable 'df'. Finally, the cleaned DataFrame 'df' is printed to the console.

# %%
# Drop missing rows in 'magnitude' column
df = df.dropna(subset=['magnitude'])

# Print the resulting dataframe
df
# Out:
#                  id  properties.mag  \
# 0        ci40189903            1.79
# 1        ci40189895            2.13
# 2      ak0233v8qay0            2.00
# 3      ak0233v8ikzw            1.20
# 4        pr71401523            3.21
# ...             ...             ...
# 12458  ak0232hn4xtc            2.10
# 12459  ak0232hn4dmo            1.60
# 12460    hv73329557            2.24
# 12461    uw61899432            1.16
# 12462    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#       properties.status  properties.sig  \
# 0             automatic              49
# 1             automatic              70
# 2             automatic              62
# 3             automatic              22
# 4              reviewed             159
# ...                 ...             ...
# 12458          reviewed              68
# 12459          reviewed              39
# 12460          reviewed              77
# 12461          reviewed              21
# 12462          reviewed               4
#
#                                         properties.types  properties.rms  \
# 0      ,focal-mechanism,nearby-cities,origin,phase-da...            0.19
# 1                    ,nearby-cities,origin,scitech-link,            0.18
# 2                                    ,origin,phase-data,            0.57
# 3                                    ,origin,phase-data,            0.54
# 4                                    ,origin,phase-data,            0.07
# ...                                                  ...             ...
# 12458                                ,origin,phase-data,            0.35
# 12459                                ,origin,phase-data,            0.17
# 12460                                ,origin,phase-data,            0.12
# 12461                                ,origin,phase-data,            0.19
# 12462                                ,origin,phase-data,            0.03
#
#       properties.type geometry.type   Longitude   Latitude  Depth        date  \
# 0          earthquake         Point -116.431168  33.267334   4.56  2023-03-25
# 1          earthquake         Point -116.977833  32.830833   5.19  2023-03-25
# 2          earthquake         Point -147.001300  61.260200   0.00  2023-03-25
# 3          earthquake         Point -148.898500  64.890000  16.70  2023-03-25
# 4          earthquake         Point  -64.826000  18.484333  75.75  2023-03-25
# ...               ...           ...         ...        ...    ...         ...
# 12458      earthquake         Point -155.396500  58.183900   1.60  2023-02-23
# 12459      earthquake         Point -152.028900  60.677600  82.40  2023-02-23
# 12460      earthquake         Point -155.395167  19.240833  30.91  2023-02-23
# 12461      earthquake         Point -120.578667  46.255333  12.96  2023-02-23
# 12462      earthquake         Point -166.884167  53.684667   8.77  2023-02-23
#
#                  place_name tsunami_occurred           magnitude
# 0                        CA               No     Local magnitude
# 1                        CA               No     Local magnitude
# 2           Southern Alaska               No     Local magnitude
# 3                    Alaska               No     Local magnitude
# 4       U.S. Virgin Islands               No  Duration magnitude
# ...                     ...              ...                 ...
# 12458      Alaska Peninsula               No     Local magnitude
# 12459                Alaska               No     Local magnitude
# 12460                Hawaii               No  Duration magnitude
# 12461            Washington               No     Local magnitude
# 12462                Alaska               No     Local magnitude
#
# [12325 rows x 17 columns]

# %% [markdown]
# Counts the number of missing values in each column. Then counts the total number of True values for each column, representing the number of missing values in each column.

# %%
# count the number of missing values in each column
missing_values = df.isnull().sum()
# print the result
print(missing_values)
# Out:
# id                   0
# properties.mag       0
# properties.place     0
# properties.time      0
# properties.status    0
# properties.sig       0
# properties.types     0
# properties.rms       0
# properties.type      0
# geometry.type        0
# Longitude            0
# Latitude             0
# Depth                0
# date                 0
# place_name           0
# tsunami_occurred     0
# magnitude            0
# dtype: int64

# %% [markdown]
# Creates a new column called "month" . The values of this new column are obtained by applying a lambda function that extracts the month value from each 'date' value . The 'map()' method is used to apply this lambda function to each 'date' value in the 'date' column. The resulting month values are then assigned to the new "month" column.

# %%
df["month"] = df['date'].map(lambda x: x.month)
df
# Out:
# <ipython-input-18-ff8591da22f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month"] = df['date'].map(lambda x: x.month)
#                  id  properties.mag  \
# 0        ci40189903            1.79
# 1        ci40189895            2.13
# 2      ak0233v8qay0            2.00
# 3      ak0233v8ikzw            1.20
# 4        pr71401523            3.21
# ...             ...             ...
# 12458  ak0232hn4xtc            2.10
# 12459  ak0232hn4dmo            1.60
# 12460    hv73329557            2.24
# 12461    uw61899432            1.16
# 12462    av91090303            0.52
#
#                                  properties.place  properties.time  \
# 0                  5km WNW of Borrego Springs, CA    1679774005670
# 1                           1km SSW of Santee, CA    1679773995770
# 2                                 Southern Alaska    1679773586327
# 3             33 km NNE of Four Mile Road, Alaska    1679771424123
# 4      17 km NNW of Cruz Bay, U.S. Virgin Islands    1679771233290
# ...                                           ...              ...
# 12458                            Alaska Peninsula    1677184513425
# 12459                39 km W of Salamatof, Alaska    1677184371205
# 12460                  9 km ENE of Pāhala, Hawaii    1677184365830
# 12461               16 km S of Harrah, Washington    1677184317290
# 12462       Fox Islands, Aleutian Islands, Alaska    1677183363890
#
#       properties.status  properties.sig  \
# 0             automatic              49
# 1             automatic              70
# 2             automatic              62
# 3             automatic              22
# 4              reviewed             159
# ...                 ...             ...
# 12458          reviewed              68
# 12459          reviewed              39
# 12460          reviewed              77
# 12461          reviewed              21
# 12462          reviewed               4
#
#                                         properties.types  properties.rms  \
# 0      ,focal-mechanism,nearby-cities,origin,phase-da...            0.19
# 1                    ,nearby-cities,origin,scitech-link,            0.18
# 2                                    ,origin,phase-data,            0.57
# 3                                    ,origin,phase-data,            0.54
# 4                                    ,origin,phase-data,            0.07
# ...                                                  ...             ...
# 12458                                ,origin,phase-data,            0.35
# 12459                                ,origin,phase-data,            0.17
# 12460                                ,origin,phase-data,            0.12
# 12461                                ,origin,phase-data,            0.19
# 12462                                ,origin,phase-data,            0.03
#
#       properties.type geometry.type   Longitude   Latitude  Depth        date  \
# 0          earthquake         Point -116.431168  33.267334   4.56  2023-03-25
# 1          earthquake         Point -116.977833  32.830833   5.19  2023-03-25
# 2          earthquake         Point -147.001300  61.260200   0.00  2023-03-25
# 3          earthquake         Point -148.898500  64.890000  16.70  2023-03-25
# 4          earthquake         Point  -64.826000  18.484333  75.75  2023-03-25
# ...               ...           ...         ...        ...    ...         ...
# 12458      earthquake         Point -155.396500  58.183900   1.60  2023-02-23
# 12459      earthquake         Point -152.028900  60.677600  82.40  2023-02-23
# 12460      earthquake         Point -155.395167  19.240833  30.91  2023-02-23
# 12461      earthquake         Point -120.578667  46.255333  12.96  2023-02-23
# 12462      earthquake         Point -166.884167  53.684667   8.77  2023-02-23
#
#                  place_name tsunami_occurred           magnitude  month
# 0                        CA               No     Local magnitude      3
# 1                        CA               No     Local magnitude      3
# 2           Southern Alaska               No     Local magnitude      3
# 3                    Alaska               No     Local magnitude      3
# 4       U.S. Virgin Islands               No  Duration magnitude      3
# ...                     ...              ...                 ...    ...
# 12458      Alaska Peninsula               No     Local magnitude      2
# 12459                Alaska               No     Local magnitude      2
# 12460                Hawaii               No  Duration magnitude      2
# 12461            Washington               No     Local magnitude      2
# 12462                Alaska               No     Local magnitude      2
#
# [12325 rows x 18 columns]

# %% [markdown]
# Imports the NumPy library and finds the minimum and maximum values for various columns. It then sets the display options for the output table, including the desired width and maximum number of columns to show.
#
# Next, the code creates a dictionary containing the minimum and maximum values for each column and their corresponding column names. It then uses this dictionary to create a new DataFrame 'data_frame' which is then printed to the console using the 'print()' function. The output shows the minimum and maximum values for each column in a tabular format, including the significance level, country, event month, magnitude, place, depth, etc.
#
# Output Explanation: The output data provides information about seismic events that have occurred in different countries, with details such as the magnitude, depth, and location of each event. It is evident from the output that the maximum magnitude recorded so far in the year 2023 is 5.90 during the month of march near Tajiskistan. In the mean time, the
# highest significance level is recorded in Tajikistan with a value of 694.

# %%
# Minimum and Maximum 
import numpy as np
sig_minimum = df.loc[df['properties.sig'].idxmin()];
sig_maximum = df.loc[df['properties.sig'].idxmax()]
mag_minimum = df.loc[df['properties.mag'].idxmin()]
mag_maximum = df.loc[df['properties.mag'].idxmax()] 
rms_minimum = df.loc[df['properties.rms'].idxmin()]
rms_maximum = df.loc[df['properties.rms'].idxmax()] 	
depth_minimum = df.loc[df['Depth'].idxmin()]
depth_maximum = df.loc[df['Depth'].idxmax()] 

desired_width = 320

pd.set_option('display.width', desired_width)

np.set_printoptions(linewidth=desired_width)
pd.set_option('display.max_columns', 12)
print(""
          ""
          ""
          "")
data = {'Type': ['Minimum', 'Maximum'],
            'Signifance Level': [sig_minimum['properties.sig'], sig_maximum['properties.sig']],
            'Country': [sig_minimum.place_name, sig_maximum.place_name],
            'Event Month': [sig_minimum.month, sig_maximum.month],
            'Magnitude': [mag_minimum['properties.mag'], mag_maximum['properties.mag']],
            'Place': [mag_minimum.place_name, mag_maximum.place_name],
            'Month': [mag_minimum.month, mag_maximum.month]}
print(""
          ""
          ""
          "")
    # Create DataFrame
data_frame = pd.DataFrame(data)
# Print the output.
print(data_frame)
# Out:
#       Type  Signifance Level      Country  Event Month  Magnitude        Place  Month
# 0  Minimum                 0       Alaska            3      -1.33       Alaska      3
# 1  Maximum               694   Tajikistan            3       5.90   Tajikistan      3

# %% [markdown]
# The below code creates a bar chart to visualize the frequency of values in the 'place_name' column that occur more than 100 times in the original DataFrame.
# *   This is implemented by  grouping the DataFrame by the 'place_name' column and counts the number of occurrences of each value using the 'size()' method. The result is a new DataFrame that contains two columns: 'place_name' and 'Count'.
# *   Next, the code filters the new DataFrame to only include values where the count is greater than 100, using the boolean indexing operator and the 'loc[]' method.
# *   Finally, the code uses the filtered DataFrame to create a bar chart using the 'px.bar()' method from Plotly Express. The x-axis of the chart represents the 'place_name' column, and the y-axis represents the count of each value. The resulting chart is then displayed using the 'show()' method.
#
# Output Explanation: It is clear from the chart that the city 'Alaska' has recorded highest number of seismic activities with a count of 6001. The second highest number 2935 events were recorded in the CA( California) city while Hawai takes the third place with 434 seismic events.

# %%
import plotly.express as px

# Count the occurrences of each value in the "category" column
value_counts = df.groupby('place_name').size().reset_index(name='Count')
# print(value_counts)
# Filter values with count greater than 100
value_counts_filtered = value_counts[value_counts['Count'] > 100]

# Create bar chart
fig = px.bar(value_counts_filtered, x='place_name', y='Count')

# Show chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="def648a7-b6c2-4d45-a5e5-196c89093ca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("def648a7-b6c2-4d45-a5e5-196c89093ca6")) {                    Plotly.newPlot(                        "def648a7-b6c2-4d45-a5e5-196c89093ca6",                        [{"alignmentgroup":"True","hovertemplate":"place_name=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[" Alaska"," CA"," Hawaii"," Montana"," Nevada"," New Mexico"," Oklahoma"," Puerto Rico"," Texas"," Washington","Alaska Peninsula"],"xaxis":"x","y":[6001,2935,434,175,237,114,146,271,113,159,199],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...

# %% [markdown]
# The below code is used to create a bar chart to visualize the frequency of values in the 'magnitude' column of the DataFrame. This can be useful for identifying the range and distribution of magnitudes in the DataFrame.
#
#
# *   It is implemented by grouping the DataFrame by the 'magnitude' column and counts the number of occurrences of each value using the 'size()' method. The result is a new DataFrame that contains two columns: 'magnitude' and 'Count'.
# *   The code then prints this DataFrame using the 'print()' method to display the count of each magnitude value in the 'magnitude' column.
# *   Finally, the code uses the original DataFrame to create a bar chart using the 'px.bar()' method from Plotly Express. The x-axis of the chart represents the 'magnitude' column, and the y-axis represents the count of each value. The resulting chart is then displayed using the 'show()' method.
#
# Output Explanation: Magnitude refers to the method or algorithm used to calculate the preferred magnitude for the event. In most of the seismic cases, 'Local Magnitude' approach is used to calculate the magnitude registered. 'Moment Magnitude' approach is the least used one.

# %%
import plotly.express as px

# Count the occurrences of each value in the "category" column
value_counts = df.groupby('magnitude').size().reset_index(name='Count')
print(value_counts)

# Create bar chart
fig = px.bar(value_counts, x='magnitude', y='Count')

# Show chart
fig.show()
# Out:
#              magnitude  Count
# 0  Body-wave magnitude    840
# 1   Duration magnitude   2797
# 2      Local magnitude   8679
# 3     Moment magnitude      9
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c658eb8f-92c9-4665-a4e8-e2331a9c0650" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c658eb8f-92c9-4665-a4e8-e2331a9c0650")) {                    Plotly.newPlot(                        "c658eb8f-92c9-4665-a4e8-e2331a9c0650",                        [{"alignmentgroup":"True","hovertemplate":"magnitude=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Body-wave magnitude","Duration magnitude","Local magnitude","Moment magnitude"],"xaxis":"x","y":[840,2797,8679,9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# #### creates a world map visualization of earthquake records
#
# The world_map() function can be used to visualize the geographical distribution of earthquake data points in a DataFrame and their association with a specified column like 'tsunami_occurred'.
#
# *   The function takes two parameters - a DataFrame data_frame and a string color.
# *   The function uses the px.scatter_geo() method from Plotly Express to create a scatter plot on a world map, where the latitude and longitude of each data point are represented by the 'Latitude' and 'Longitude' columns of the DataFrame. The color of each data point is determined by the column specified in the color parameter.
# *   The function sets the projection of the map to "natural earth" using the 'projection' parameter of px.scatter_geo().
# *   The function then updates the layout of the plot to include a title and sets the x-axis of the title to 0.5 using the 'title' and 'title_x' parameters of fig.update_layout().
# *   Finally, the function displays the plot using the 'show()' method of fig.
#
# Output Explanation : It is evident from the graph that most of the seismic events are registered in the continent 'North America' where the least occurred in the Africa continent. In the same time, in terms of ocean most of the events were recorded in the 'pacific ocean'.

# %%
def world_map(data_frame, color):
    fig = px.scatter_geo(data_frame, lat='Latitude', lon='Longitude', color=color, projection="natural earth")
    fig.update_layout(title='Earthquake Records all over the world', title_x=0.5)
    fig.show()
world_map(df,'tsunami_occurred')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ba8e9d28-d4af-4fd1-bef7-dca8f82f3fac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba8e9d28-d4af-4fd1-bef7-dca8f82f3fac")) {                    Plotly.newPlot(                        "ba8e9d28-d4af-4fd1-bef7-dca8f82f3fac",                        [{"geo":"geo","hovertemplate":"tsunami_occurred=No<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[33.267334,32.8308333,61.2602,64.89,18.4843333333333,17.8248333333333,33.5781667,60.018,51.8378333333333,33.0335007,37.5393333,19.2119998931885,19.253999710083,33.7293333,38.8014984,51.8646666666667,33.5223333,37.4295,36.2529,57.0511,33.5298333,57.1276,60.3796,33.4355,58.0256,38.7993317,51.8648333333333,51.8631666666667,63.2707,38.8310013,33.2751667,33.5311667,33.1865,19.156665802002,35.5083333,35.85469437,38.8268318,56.8918333333333,60.3889,35.9241667,19.2294998168945,56.9476,51.8601666666667,38.8269997,59.629,17.978,28.64776611,17.9486666666667,33.497,61.2532,33.6863333,38.5699997,62.7102,51.8626666666667,51.8553333333333,19.3810005187988,32.7705,33.8045,38.8296661,62.3095,38.1404,37.8653333,56.8571666666667,38.7804985,56.8541666666667,60.3607,56.8708333333333,57.8249,33.444,22.6673,38.7885017,17.9675,33.7636667,38.8359985,38.8261681,36.6100006,63.4913,61.0095,38.8243332,64.6966,60.6278,62.2
# *   The function then updates the text values of each bar using the 'texttemplate' and 'textposition' parameters of fig.update_traces(). The 'text' parameter is used to specify the text values to be displayed on each bar, and the 'textposition' parameter is used to specify the position of the text values relative to the bars.
# *   The function sets the title of the chart using the 'title' parameter of px.bar().
# *   Finally, the function displays the chart using the 'show()' method of fig.

# %%
def stack_bar_with_count(data_frame: object, values: object, names: object, color: object,
                         text: object, title: object) -> object:
    fig = px.bar(data_frame, x=values, y=names, color=color, height=700, text=text, title=title)
    fig.update_traces(texttemplate='%{text:s}', textposition='outside')
    fig.show()

# %% [markdown]
# The below code performs two groupby operations on the DataFrame df, and prints the resulting DataFrames.
#
# *   In the first groupby operation, the code groups the DataFrame by two columns, 'properties.type' and 'tsunami_occurred'. It then aggregates the 'properties.type' column using the 'count' method and assigns the resulting Series to the variable 'count'. Finally, it resets the index of the resulting DataFrame using the 'reset_index' method, and assigns the resulting DataFrame to the variable 'tsunami_result'. The resulting DataFrame contains three columns: 'properties.type', 'tsunami_occurred', and 'count', where the 'count' column contains the frequency of occurrences of each combination of values in the 'properties.type' and 'tsunami_occurred' columns.
#
# *   In the second groupby operation, the code groups the DataFrame by two columns, 'properties.type' and 'magnitude'. It then aggregates the 'properties.type' column using the 'count' method and assigns the resulting Series to the variable 'count'. Finally, it resets the index of the resulting DataFrame using the 'reset_index' method, and assigns the resulting DataFrame to the variable 'result'. The resulting DataFrame contains three columns: 'properties.type', 'magnitude', and 'count', where the 'count' column contains the frequency of occurrences of each combination of values in the 'properties.type' and 'magnitude' columns.
#
# Output Explanation: 'Local Magnitude' approach mainly is used to calculate the magnitude of the event in case of queryblast. Eventhough 'Local Magnitude' approach is mostly used for calculation in case of earthquake, still 'Duration Magnitude' approach is involved equally for the evaluation purpose.

# %%
tsunami_result=df.groupby(['properties.type','tsunami_occurred'])['properties.type'].aggregate('count').reset_index(name="count")
result=df.groupby(['properties.type','magnitude'])['properties.type'].aggregate('count').reset_index(name="count")

print(result)
# Out:
#   properties.type            magnitude  count
# 0      earthquake  Body-wave magnitude    840
# 1      earthquake   Duration magnitude   2791
# 2      earthquake      Local magnitude   8518
# 3      earthquake     Moment magnitude      9
# 4       explosion   Duration magnitude      3
# 5       explosion      Local magnitude     62
# 6       ice quake      Local magnitude     32
# 7     other event      Local magnitude      8
# 8    quarry blast   Duration magnitude      3
# 9    quarry blast      Local magnitude     59

# %% [markdown]
# The below code creates a bar chart using the px.bar() function from the Plotly Express library. The function takes the DataFrame result as the first argument, and specifies the 'properties.type' column as the x-axis and the 'count' column as the y-axis. The resulting chart shows the frequency or count of occurrences of each value in the 'properties.type' column.
#
# Output Explanation: In the total number of events recorded, around 8000 events are due to earthquake and 62 events recorded are due to explosion.

# %%
import plotly.express as px

# Create bar chart
fig = px.bar(result, x='properties.type', y='count')

# Show chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="91389ae0-b73d-470d-8bc1-a8617516e73d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91389ae0-b73d-470d-8bc1-a8617516e73d")) {                    Plotly.newPlot(                        "91389ae0-b73d-470d-8bc1-a8617516e73d",                        [{"alignmentgroup":"True","hovertemplate":"properties.type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["earthquake","earthquake","earthquake","earthquake","explosion","explosion","ice quake","other event","quarry blast","quarry blast"],"xaxis":"x","y":[840,2791,8518,9,3,62,32,8,3,59],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# Output Explanation: The below chart dsiplays that only in 6 events tsunami is triggered because of the earthquake and an in other events like explosion,icequake,quarryblast and so on not even once,tsunami is triggered.

# %%
stack_bar_with_count(tsunami_result, 'properties.type', 'count', 'tsunami_occurred', 'count',
                         "Occurrence of tsunami due to earthquake")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e0c4082e-3f7b-47f6-bcbc-8db9b885da31" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0c4082e-3f7b-47f6-bcbc-8db9b885da31")) {                    Plotly.newPlot(                        "e0c4082e-3f7b-47f6-bcbc-8db9b885da31",                        [{"alignmentgroup":"True","hovertemplate":"tsunami_occurred=No<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[12152.0,65.0,32.0,8.0,62.0],"textposition":"outside","x":["earthquake","explosion","ice quake","other event","quarry blast"],"xaxis":"x","y":[12152,65,32,8,62],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"},{"alignmentgroup":"True","hovertemplate":"tsunami_occurred=Yes<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["earthquake"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity": ...

# %% [markdown]
# Output Explanation: Different approaches were used only to calculate the earthquake activities. But in other cases, only local magnitude is used.

# %%
stack_bar_with_count(result, 'properties.type', 'count', 'magnitude', 'count',
                         "Magnitude levels of earthquake")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="beac89f4-664d-42f4-a6ae-d33bba0e3d91" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beac89f4-664d-42f4-a6ae-d33bba0e3d91")) {                    Plotly.newPlot(                        "beac89f4-664d-42f4-a6ae-d33bba0e3d91",                        [{"alignmentgroup":"True","hovertemplate":"magnitude=Body-wave magnitude<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Body-wave magnitude","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Body-wave magnitude","offsetgroup":"Body-wave magnitude","orientation":"v","showlegend":true,"text":[840.0],"textposition":"outside","x":["earthquake"],"xaxis":"x","y":[840],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"},{"alignmentgroup":"True","hovertemplate":"magnitude=Duration magnitude<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Duration magnitude","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Duration magnitude","offsetgroup":"Duration magnitude","orientation":"v","showlegend":true,"text":[2791.0,3.0,3.0],"textposition":"outside","x":["earthquake","explosion","quarry blast"],"xaxis":"x","y":[2791,3,3],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"},{"alignmentgroup":"True","hovertemplate":"magnitude=Local magnitude<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Local magnitude","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Local magnitude","offsetgroup":"Local magnitude","orientation":"v","showlegend":true,"text":[8518.0,62.0,32.0,8.0,59.0],"textposition":"outside","x":["earthquake","explosion","ice quake","other event","quarry blast"],"xaxis":"x","y":[8518,62,32,8,59],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"},{"alignmentgroup":"True","hovertemplate":"magnitude=Moment magnitude<br>properties.type=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Moment magnitude","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Moment magnitude","offsetgroup":"Moment magnitude","orientation":"v","showlegend":true,"text":[9.0],"textposition":"outside","x":["earthquake"],"xaxis":"x","y":[9],"yaxis":"y","type":"bar","texttemplate":"%{text:s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %% [markdown]
# # Challenges Faced
#
# Tried converting the city names to country and continent names. But it was really difficult as the number of records is greater than 10000. Tried filtering out only the february month data but still the conversion process took too long. However converted from city to country for only february data.
#
# While converting from country to continent most of the country names had special characters and are not clear. so it was difficult to find the continent name. So those codes were commented out in the last

# %%
# march_df = df[df['month'].dt.month == 3]
feb_month = df[df['month'] ==2]
feb_month
# Out:
#                  id  properties.mag                       properties.place  properties.time properties.status  properties.sig  ...      Depth        date        place_name tsunami_occurred           magnitude  month
# 10429    av91091243            1.64                92 km W of Adak, Alaska    1677628734320          reviewed              41  ...   3.630000  2023-02-28            Alaska               No     Local magnitude      2
# 10430    av91777531            1.57                92 km W of Adak, Alaska    1677628724110          reviewed              38  ...   5.900000  2023-02-28            Alaska               No     Local magnitude      2
# 10431    tx2023edur            1.90            37 km WSW of Mentone, Texas    1677628719055          reviewed              56  ...   6.440063  2023-02-28             Texas               No     Local magnitude      2
# 10432    av91091248            0.92                93 km W of Adak, Alaska    1677628717920          reviewed              13  ...   6.890000  2023-02-28            Alaska               No     Local magnitude      2
# 10433    tx2023edup            2.90            37 km WSW of Mentone, Texas    1677628656490          reviewed             129  ...   7.249866  2023-02-28             Texas               No     Local magnitude      2
# ...             ...             ...                                    ...              ...               ...             ...  ...        ...         ...               ...              ...                 ...    ...
# 12458  ak0232hn4xtc            2.10                       Alaska Peninsula    1677184513425          reviewed              68  ...   1.600000  2023-02-23  Alaska Peninsula               No     Local magnitude      2
# 12459  ak0232hn4dmo            1.60           39 km W of Salamatof, Alaska    1677184371205          reviewed              39  ...  82.400000  2023-02-23            Alaska               No     Local magnitude      2
# 12460    hv73329557            2.24             9 km ENE of Pāhala, Hawaii    1677184365830          reviewed              77  ...  30.910000  2023-02-23            Hawaii               No  Duration magnitude      2
# 12461    uw61899432            1.16          16 km S of Harrah, Washington    1677184317290          reviewed              21  ...  12.960000  2023-02-23        Washington               No     Local magnitude      2
# 12462    av91090303            0.52  Fox Islands, Aleutian Islands, Alaska    1677183363890          reviewed               4  ...   8.770000  2023-02-23            Alaska               No     Local magnitude      2
#
# [2000 rows x 18 columns]

# %% [markdown]
# The given code defines a function called cityToCountry which takes a city name as an argument and returns the name of the country that the city is located in.

# %%
from geopy.geocoders import Nominatim
def cityToCountry(cityName):
  geolocator = Nominatim(user_agent="my_app")
  city_name = cityName.strip();

  if(city_name == 'Kuril Islands'):
    country_name= 'Russia'
  elif(city_name == 'Tajikistan'):
    country_name= 'Tajikistan'
  elif(city_name == 'MX'):
    country_name= 'Mexico'
  elif(city_name == 'off the coast of Costa Rica'):
    country_name= 'Costa Rica'
  elif(city_name == 'Central Turkey'):
    country_name= 'Turkey'
  elif(city_name == 'Norwegian Sea'):
    country_name= 'Norway'
  elif(city_name == 'Fiji' or city_name=='south of the Fiji Islands'):
    country_name= 'Fiji'
  elif(city_name == 'California-Nevada border region'):
    country_name= 'United States'
  elif(city_name == 'Papua New Guinea'):
    country_name= 'Papua New Guinea'
  elif(city_name == 'New Zealand' or city_name== 'Kermadec Islands'):
    country_name= 'New Zealand'
  elif(city_name == 'Puerto Rico region'):
    country_name= 'United States'
  elif(city_name == 'Iran'):
    country_name= 'Iran'
  elif(city_name == 'Peru'):
    country_name= 'Peru'
  elif(city_name == 'Eastern Xizang' or city_name =='China'):
    country_name= 'China'
  elif(city_name == 'off the coast of Orgeon' or city_name=='south of Alaska'):
    country_name= 'United States'
  elif(city_name == 'Iraq'):
    country_name= 'Iraq'
  elif(city_name == 'Japan'):
    print("Japan££££££££")
    country_name= 'Japan'
  elif(city_name == 'Peru'):
    country_name= 'Peru'
  elif(city_name == 'Turkey'):
    country_name= 'Turkey'
  else:
    location = geolocator.geocode(city_name, exactly_one=True, timeout=10000)
    if location:
      country_name = location.raw['display_name'].split(",")[-1].strip()
      # print(f"The country name for {city_name} is {country_name}")
    else:
      # print(f"No location found for {city_name}")
      country_name='Unknown'
  # df[country_name]=country_name;
  # print(city_name,"******",country_name);
  return country_name;

# %% [markdown]
# used to extract the country name from the place_name column and add it as a new column in the feb_month DataFrame.

# %%
feb_month['country_name'] = feb_month["place_name"].apply(lambda x: cityToCountry(x))
# Out:
# Alaska ****** United States
# Alaska ****** United States
# Texas ****** United States
# Alaska ****** United States
# Texas ****** United States
# Alaska ****** United States
# Oklahoma ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska Peninsula ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# central Turkey ****** Türkiye
# Texas ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Texas ****** United States
# Texas ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# New Zealand ****** New Zealand
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# CA ****** Canada
# CA ****** Canada
# CA ****** Canada
# Alaska Peninsula ****** United States
# Washington ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Alaska ****** United States
# Indonesia ****** Indonesia
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska Peninsula ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Japan££££££££
# Japan ****** Japan
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Puerto Rico ****** United States
# New Mexico ****** United States
# CA ****** Canada
# Alaska ****** United States
# CA ****** Canada
# Hawaii ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Hawaii ****** United States
# CA ****** Canada
# Alaska ****** United States
# Puerto Rico ****** United States
# Washington ****** United States
# Philippines ****** Philippines
# Chile ****** Chile
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Southern Alaska ****** Россия
# CA ****** Canada
# CA ****** Canada
# Puerto Rico ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska Peninsula ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# No location found for Idaho-Montana border region
# Idaho-Montana border region ****** Unknown
# Hawaii ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Afghanistan ****** افغانستان
# Alaska Peninsula ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Albania ****** Shqipëria
# Alaska ****** United States
# Hawaii ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Utah ****** United States
# Texas ****** United States
# Puerto Rico ****** United States
# Philippines ****** Philippines
# CA ****** Canada
# CA ****** Canada
# CA ****** Canada
# Japan££££££££
# Japan ****** Japan
# Southern Alaska ****** Россия
# Northern California ****** Κύπρος - Kıbrıs
# CA ****** Canada
# Alaska ****** United States
# CA ****** Canada
# Puerto Rico ****** United States
# Alaska ****** United States
# Alaska Peninsula ****** United States
# Alaska ****** United States
# CA ****** Canada
# Fiji region ****** Philippines
# Alaska ****** United States
# Nevada ****** United States
# Alaska ****** United States
# CA ****** Canada
# Iran ****** Iran
# Greece ****** Ελλάς
# CA ****** Canada
# CA ****** Canada
# California ****** United States
# New Mexico ****** United States
# Alaska ****** United States
# Washington ****** United States
# Alaska ****** United States
# Alaska ****** United States
# New Mexico ****** United States
# Puerto Rico ****** United States
# Central Turkey ****** Turkey
# Puerto Rico ****** United States
# Alaska Peninsula ****** United States
# CA ****** Canada
# Alaska ****** United States
# CA ****** Canada
# Turkey ****** Turkey
# Southern Alaska ****** United States
# Molucca Sea ****** Molucca Sea
# Alaska ****** United States
# Central Alaska ****** United States
# Puerto Rico region ****** United States
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Washington ****** United States
# Fiji region ****** Philippines
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Alaska ****** United States
# Fiji region ****** Philippines
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Hawaii ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Chile ****** Chile
# Alaska ****** United States
# New Mexico ****** United States
# Alaska ****** United States
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# CA ****** Canada
# CA ****** Canada
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
# Alaska ****** United States
#
# ...             ...             ...                                    ...              ...               ...             ...  ...         ...               ...              ...                 ...    ...            ...
# 12458  ak0232hn4xtc            2.10                       Alaska Peninsula    1677184513425          reviewed              68  ...  2023-02-23  Alaska Peninsula               No     Local magnitude      2  United States
# 12459  ak0232hn4dmo            1.60           39 km W of Salamatof, Alaska    1677184371205          reviewed              39  ...  2023-02-23            Alaska               No     Local magnitude      2  United States
# 12460    hv73329557            2.24             9 km ENE of Pāhala, Hawaii    1677184365830          reviewed              77  ...  2023-02-23            Hawaii               No  Duration magnitude      2  United States
# 12461    uw61899432            1.16          16 km S of Harrah, Washington    1677184317290          reviewed              21  ...  2023-02-23        Washington               No     Local magnitude      2  United States
# 12462    av91090303            0.52  Fox Islands, Aleutian Islands, Alaska    1677183363890          reviewed               4  ...  2023-02-23            Alaska               No     Local magnitude      2  United States
#
# [2000 rows x 19 columns]

# %%
# !pip install pycountry
# !pip install pycountry-convert
# import pycountry_convert as pc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 44.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pycountry) (67.6.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681847 sha256=be5636ac0b40ec28bf45ecc579b38ad0b9eb3560e72b9e5cc101afa8d6445710
#   Stored in directory: /root/.cache/pip/wheels/47/15/92/e6dc85fcb0686c82e1edbcfdf80cfe4808c058813fed0baa8f
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry-convert
#   Downloading pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: wheel>=0.30.0 in /usr/local/lib/python3.9/dist-packages (from pycountry-convert) (0.40.0)
# Collecting repoze.lru>=0.7
#   Downloading repoze.lru-0.7-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycountry>=16.11.27.1 in /usr/local/lib/python3.9/dist-packages (from pycountry-convert) (22.3.5)
# Collecting pytest-mock>=1.6.3
#   Downloading pytest_mock-3.10.0-py3-none-any.whl (9.3 kB)
# Collecting pprintpp>=0.3.0
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pytest>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from pycountry-convert) (7.2.2)
# Collecting pytest-cov>=2.5.1
#   Downloading pytest_cov-4.0.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pycountry>=16.11.27.1->pycountry-convert) (67.6.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (22.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (23.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest>=3.4.0->pycountry-convert) (2.0.0)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.2.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 KB 6.0 MB/s eta 0:00:00
# Installing collected packages: repoze.lru, pprintpp, coverage, pytest-mock, pytest-cov, pycountry-convert
# Successfully installed coverage-7.2.2 pprintpp-0.4.0 pycountry-convert-0.7.2 pytest-cov-4.0.0 pytest-mock-3.10.0 repoze.lru-0.7

# %%
# import geopy
# import pycountry
# !pip install country_converter

# import country_converter as coco

# def get_continent(country):
#     # Get the country code for the given country
#     continent=''
#     country_code=''
#     # print(country)
#       country_code = pycountry.countries.get(name=country).alpha_2
#       continent = 'Unknown'
#     # Define a dictionary mapping country codes to continents
#       continent_dict = {
#         'AS': 'Asia',
#         'EU': 'Europe',
#         'AF': 'Africa',
#         'NA': 'North America',
#         'SA': 'South America',
#         'OC': 'Oceania',
#         'AN': 'Antarctica'
#       }
    
#     # Get the continent for the given country code
#       try:
#           continent_code = coco.convert(names=country_code, to='Continent_Code')
#           continent = continent_dict[continent_code[0]]
#       except KeyError:
#           continent = 'Unknown'
#     print(country,'country',continent)
    
#     return continent
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting country_converter
#   Downloading country_converter-1.0.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from country_converter) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->country_converter) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country_converter
# Successfully installed country_converter-1.0.0

# %%
# feb_month['Continent'] = feb_month["country_name"].apply(lambda x: get_continent(x))
# Out:
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Türkiye country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# New Zealand country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Indonesia country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Japan country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Philippines country
# Chile country
# United States country
# United States country
# United States country
# United States country
# Россия country Unknown
# Canada country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# Unknown country Unknown
# United States country
# United States country
# Canada country
# Canada country
# افغانستان country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# Shqipëria country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Philippines country
# Canada country
# Canada country
# Canada country
# Japan country
# Россия country Unknown
# Κύπρος - Kıbrıs country Unknown
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Philippines country
# United States country
# United States country
# United States country
# Canada country
# Iran country Unknown
# Ελλάς country Unknown
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Turkey country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Turkey country
# United States country
# Molucca Sea country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Philippines country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Philippines country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Chile country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Turkey country
# United States country
# United States country
# Россия country Unknown
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Philippines country
# Canada country
# México country Unknown
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Chile country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# New Zealand country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Unknown country Unknown
# Papua New Guinea country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Chile country
# Argentina country
# Россия country Unknown
# United States country
# Prince Edward Islands Southwest Indian Ridge Restricted Zone country Unknown
# United States country
# Canada country
# Tajikistan country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# Canada country
# United States country
# Canada country
# Canada country
# Japan country
# United States country
# Canada country
# Canada country
# United States country
# Canada country
# Canada country
# Canada country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Perú country Unknown
# United States country
# Papua New Guinea country
# United States country
# Papua New Guinea country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Turkey country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Chile country
# Chile country
# United States country
# Australia country
# United States country
# Tajikistan country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Philippines country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# Unknown country Unknown
# Canada country
# Chile country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# France country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Россия country Unknown
# Canada country
# افغانستان country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Mar Tirreno / Mer Tyrrhénienne country Unknown
# United States country
# United States country
# Canada country
# United States country
# Papua New Guinea country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Chile country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# China country
# United States country
# United States country
# Россия country Unknown
# Canada country
# Canada country
# United States country
# United States country
# Japan country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Philippines country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Laut Banda country Unknown
# United States country
# United States country
# United States country
# Canada country
# Papua New Guinea country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Philippines country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Unknown country Unknown
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Bolivia country Unknown
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Guatemala country
# United States country
# Solomon Islands country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Peru country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Unknown country Unknown
# United States country
# Unknown country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# Mexico country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
#

# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Unknown country Unknown
# Canada country
# United States country
# United States country
# United States country
# Japan country
# Canada country
# United States country
# Canada country
# Turkey country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Honduras country
# United States country
# United States country
# Canada country
# México country Unknown
# United States country
# United States country
# United States country
# Chile country
# United States country
# Canada country
# México country Unknown
# United States country
# United States country
# Canada country
# México country Unknown
# United States country
# United States country
# Canada country
# United States country
# Россия country Unknown
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Canada country
# Canada country
# Canada country
# Indonesia country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Unknown country Unknown
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# Россия country Unknown
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Japan country
# United States country
# México country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Indonesia country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# Unknown country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Turkey country
# Canada country
# United States country
# Japan country
# Canada country
# United States country
# United States country
# Turkey country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United Kingdom country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# Unknown country Unknown
# Unknown country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Россия country Unknown
# Canada country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# United States country
# Canada country
# Tajikistan country
# United States country
# Canada country
# United States country
# United States country
# سوريا country Unknown
# United States country
# Philippines country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Philippines country
# United States country
# United States country
# Philippines country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Argentina country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Unknown country Unknown
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# France country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# Canada country
# Türkiye country Unknown
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Unknown country Unknown
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Philippines country
# United States country
# Canada country
# Mexico country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Fiji country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Tonga country
# Canada country
# United States country
# United States country
# Tajikistan country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# España country Unknown
# United States country
# Canada country
# United States country
# United States country
# United States country
# Indonesia country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# Canada country
# India country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Chile country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Turkey country
# United States country
# United States country
# Canada country
# United States country
# Papua New Guinea country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# México country Unknown
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Papua New Guinea country
# Bolivia country Unknown
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Mona Passage country Unknown
# Canada country
# United States country
# Cuba country
# United States country
# United States country
# United States country
# Canada country
# پاکستان country Unknown
# United States country
# United States country
# Canada country
# Chile country
# Canada country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# مصر country Unknown
# United States country
# Canada country
# Canada country
# Guatemala country
# Canada country
# Canada country
# United States country
# United States country
# Canada country
# Japan country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# Canada country
# Canada country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# United States country
# <ipython-input-34-c7ee7242a1f9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Conclusion:
#
# The analysis of earthquake data using the USGS API provides valuable insights into the frequency, magnitude, and distribution of earthquakes. The analysis shows that there have been a significant number of earthquakes recorded over the past few decades, with the majority of them being of low magnitude. However, there have also been several large earthquakes that resulted in significant damage and loss of life.
#
# Tried converting the city names to country and continent names. But it was really difficult as the number of records is greater than 10000. Tried filtering out only the february month data but still the conversion process took too long. However converted from city to country for only february data. While converting from country to continent most of the country names had special characters and are not clear. so it was difficult to find the continent name.
#
# The analysis also reveals that earthquakes tend to occur in specific regions, such as the Pacific Ring of Fire, which is a highly seismically active area. Additionally, there appears to be a correlation between the magnitude of earthquakes and the frequency at which they occur.
#
# Data visualizations, such as maps and plots, are used to better illustrate the distribution and frequency of earthquakes. These visualizations are useful in conveying the information to a wider audience and can also aid in identifying patterns and trends that may not be immediately apparent from the raw data.
#
# Overall, the analysis of earthquake data can be used to better understand the patterns and trends of earthquakes, and to develop strategies for predicting and mitigating their impact. Further analysis of this data could involve exploring the relationship between earthquakes and other natural phenomena, such as volcanic activity or changes in ocean currents, to gain a more comprehensive understanding of seismic events.
